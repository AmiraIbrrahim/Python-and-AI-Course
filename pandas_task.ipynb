# %%
#import pandas
import pandas as pd

#create dataframe
data = [{'Name' : 'Alice', 'Age' : 20, 'Grade' : 'A', 'Marks' : 85},
        {'Name' : 'Bob', 'Age' : 22, 'Grade' : 'B', 'Marks' : 78},
        {'Name' : 'Charlie', 'Age' : 19, 'Grade' : 'A', 'Marks' : 92},
        {'Name' : 'David', 'Age' : 21, 'Grade' : 'C', 'Marks' : 65},
        {'Name' : 'Eva', 'Age' : 20, 'Grade' : 'B', 'Marks' : 74}]

students_data = pd.DataFrame(data)

#display first 3 rows
students_data.head(3)
# Out:
#       Name  Age Grade  Marks
# 0    Alice   20     A     85
# 1      Bob   22     B     78
# 2  Charlie   19     A     92

# %%
#select and display name and marks columns
students_data[['Name', 'Marks']]
# Out:
#       Name  Marks
# 0    Alice     85
# 1      Bob     78
# 2  Charlie     92
# 3    David     65
# 4      Eva     74

# %%
#filter and show grade A students
students_data[students_data['Grade']=='A']
# Out:
#       Name  Age Grade  Marks
# 0    Alice   20     A     85
# 2  Charlie   19     A     92
